# %%
# we should be able to:
# Add data anywhere in the list (beginning, anywhere in the middle or at the end of our list)
# Remove data from anywhere in the list.
# Search for, or access data(which may be anywhere in the list)

# %%
# LinkedList 

class Node:
    def __init__(self, data):
        self.data = data           # a class attribute is just a variable that belongs to a class 
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        self.head = None
        
    def get_node(self, target): # a method is just a function that belongs to a class 
        current = self.head
        while current:          # this is shorthand for "while current != None"
            if current.data == target:
                return current
            current = current.next
        raise ValueError("Node not found.")
        
    def prepend(self):
        new_node = Node(data)
        if self.head != None: #this means, we already have data in our list (if true)
            new_node.next = self.head
        self.head = new_node 
        
    def insert_after_value(self, data, target): #insert "data" after the "target" value.
        target_node = self.get_node_by_value(target)
        new_node = Node(data)
        target_node.next = new_node 
        
    def insert_before_value(self, data, target):
        current = self.head
        if current.data == target:
            self.prepend(data)
        else:
            while current.next:
                previous = current
                current = current.next
                if current.data == target
                    new_node = Node(data)
                    new_node.next = current
                    previous.next = new_node 
    
    def insert_after_index(self, data, index):
        current = self.head
        new_node = Node(data)
        found = False 
        count = 0 
        while current and found == False:
            if count == index:
                found == True
                current.next = new_node
            else: 
                current = current.next
                count += 1                #same as "count = count+1"
        raise IndexError("list index out of range")
        
    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node 
        else:
            while current.next:
                current = current.next 
            current.next = new_node 
            
    def remove_by_value(self, target):
        current = self.head
        if current.data == target:
            self.head = current.next
        else:
            found = False
            while current and not found:
                previos = current
                current = current.next
                if current.data == target:
                    found = True 
                    previous.next = current.next
            if not found:
                raise ValueError("Value not found in list")
                
    def search(self, value): #return True or False, depending on whether or not 
        pass                 # the value is in the list 
    
    def index(self, value):  #return the value of a node given an index. 
        pass

# %%
class DNode:
    def __init__(self, data):
        self.data = data
        self.next = None 
        self.prev = None

# %%
class DLL:
    def __init__(self):
        self.head = None 
        
    def append(self, data):
        new_node = DNode()
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next           # once we exit this while loop. we will have reached the tail
                new_node.prev = current 
                
    def insert_before(self,data):
        new_node = DNode(data)
        new_node.next = self.head 
        new_node.prev = none      
        if self.head is not None: 
            self.head.prev = new_node
        self.head = new_node
